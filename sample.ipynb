# %%
class Animal():
    def eat(self):
        print("animal eats food")
class Dog(Animal):
    def fly(self):
        print("dog is barking")

class parrot(Dog):
    def speak(self):
        print("parrot is speaking")
c=parrot()
c.eat()
c.fly()
c.speak()
# Out:
# animal eats food
# dog is barking
# parrot is speaking

# %%
class camera():
    def call(self):
        print("taking picture")
class musicplayer():
    def play(self):
        print("music is playing")
class smartphone(camera,musicplayer):
    def calling(self):
        print("smartphone is playing")
d=smartphone()
d.call()
d.play()
d.calling()
# Out:
# taking picture
# music is playing
# smartphone is playing

# %%
class person():
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print("name is : "+ self.name)
        print("age is :  "+ str(self.age))
class Employee(person):
    def __init__(self,name,age,salary):
        super().__init__(name,age)
        self.salary=salary
    def display1(self):
        print("salary is "+ str(self.salary))
c=Employee("Julian",21,20000)
c.display()
c.display1()
# Out:
# name is : Julian
# age is :  21
# salary is 20000

# %%
class person():
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print("Name is : " + self.name)
        print("Age is : " + str(self.age))


class Employee(person):
    def __init__(self, name, age, salary):
        super().__init__(name, age)
        self.salary = salary

    def display1(self):
        print("Salary is : " + str(self.salary))


c = Employee("Julian", 21, 20000)
c.display()
c.display1()
# Out:
# Name is : Julian
# Age is : 21
# Salary is : 20000

# %%
class student():
    def __init__(self,name,age):
        self.name = name
        self.age = age

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def show_balance(self):
        print("Balance is:", self.__balance)



account = BankAccount(5000)

account.show_balance()

print(account.__balance)
# Out:
# Balance is: 5000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 16
#      12 # Access balance using method
#      13 account.show_balance()
#      14
#      15 # Try accessing private variable directly
# ---> 16 print(account.__balance)
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance

    def show_balance(self):
        print("Balance is:", self.__balance)


account = BankAccount(5000)

try:
    print(account.__balance)
except AttributeError:
    print(" Cannot access private variable directly.")

# Correct way
account.show_balance()
# Out:
#  Cannot access private variable directly.
# Balance is: 5000

# %%
class wallet():
    def __init__(self,money):
        self.__money= money
    def deposit(self,amount):
        self.__money += amount
    def show_money(self):
        print("Money is:",self.__money)
c=wallet(900)
c.deposit(100)
c.show_money()
# Out:
# Money is: 1000

# %%
class Atm():
    def __init__(self):
        self.__balance = 100000
    def withdraw(self,amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawal Successful")
            print("the remaining balance is:",self.__balance)
        else:
            print("Insufficient Balance")
c=Atm()
c.withdraw(1000)
c.withdraw(1100000)
# Out:
# Withdrawal Successful
# the remaining balance is: 99000
# Insufficient Balance

# %%
class ATM:
    def __init__(self):
        self.__balance = 100000   # Private variable

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print("Withdrawal Successful")
            print("Remaining Balance:", self.__balance)
        else:
            print("Insufficient Balance")


# Create object
a = ATM()

# Withdraw amount
a.withdraw(25000)
a.withdraw(80000)
# Out:
# Withdrawal Successful
# Remaining Balance: 75000
# Insufficient Balance

# %%
class Book:
    def __init__(self, title, author):
        self.__title = title
        self.__author = author

    def display(self):
        print("Title is :", self.__title)
        print("Author is :", self.__author)


class Library(Book):
    def __init__(self, title, author):
        super().__init__(title, author)
        self.__available = True

    def borrow_book(self):
        if self.__available:
            self.__available = False
            print("Book borrowed successfully.")
        else:
            print("Book is already borrowed.")

    def check_availability(self):
        if self.__available:
            print("Book is available.")
        else:
            print("Book is not available.")


c = Library("Sneham", "Royal")

c.display()
c.borrow_book()
c.check_availability()
# Out:
# Title is : Sneham
# Author is : Royal
# Book borrowed successfully.
# Book is not available.

# %%
class Animal:
    def sound(self):
        print("Animals make sounds")

class Dog(Animal):
    def sound(self):
        print("Dog barks")
class Cat(Animal):
    def sound(self):
        print("Cat is meowing")

d = Dog()
c=Cat()
d.sound()
c.sound()
# Out:
# Dog barks
# Cat is meowing

# %%
class Dog:
    def sound(self):
        print("Dog barks")
class Cat:
    def sound(self):
        print("Cat is meowing")
def type_sound(janthuvulu):
    janthuvulu.sound()

type_sound(Dog())
type_sound(Cat())
# Out:
# Dog barks
# Cat is meowing

# %%
class cal:
    def add(self,a,b,c=0,d=0):
        return a+b+c+d
obj=cal()
print(obj.add(1,2,3,4))
print(obj.add(1,2,3))
print(obj.add(1,2))
# Out:
# 10
# 6
# 3

# %%
from abc import ABC,abstractmethod
class shape(ABC):
    @abstractmethod
    def area(self):
        pass
class rectangle(shape):
    def __init__(self,length,breadth):
        self.length = length
        self.breadth = breadth
    def area(self):
        print(self.length*self.breadth)
r=rectangle(5,6)
r.area()
# Out:
# 30

# %%
from abc import ABC, abstractmethod

class Shape(ABC):

    @abstractmethod
    def area(self):
        pass


class Circle(Shape):

    def __init__(self, radius):
        self.radius = radius

    def area(self):
        result = 3.14 * self.radius * self.radius
        print("Area of Circle is:", result)


c = Circle(5)
c.area()
# Out:
# Area of Circle is: 78.5

# %%
class vehicle():
